# %% [markdown]
# # Корреляция Пирсона

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Foodmart product sales

# %%
sales = pd.read_csv('../../static/foodmart.sales.tsv', sep = '\t', header = 0, parse_dates = [2])

# %%
sales.head()
# Out:
#    product_id  store_id       date  sales           product_name
# 0           4         6 1997-01-01      4  Washington Cream Soda
# 1           4         7 1997-01-05      3  Washington Cream Soda
# 2           4         6 1997-01-06      2  Washington Cream Soda
# 3           4        17 1997-01-11      2  Washington Cream Soda
# 4           4        24 1997-01-11      2  Washington Cream Soda

# %%
products = pd.read_csv('../../static/foodmart.products.tsv', sep = '\t', header = 0)

# %%
products.head()
# Out:
#    product_class_id  product_id  brand_name                 product_name  \
# 0                30           1  Washington       Washington Berry Juice
# 1                52           2  Washington       Washington Mango Drink
# 2                52           3  Washington  Washington Strawberry Drink
# 3                19           4  Washington        Washington Cream Soda
# 4                19           5  Washington         Washington Diet Soda
#
#            SKU   SRP  gross_weight  net_weight  recyclable_package  low_fat  \
# 0  90748583674  2.85          8.39        6.39               False    False
# 1  96516502499  0.74          7.42        4.42               False     True
# 2  58427771925  0.83         13.10       11.10                True     True
# 3  64412155747  3.64         10.60        9.60                True    False
# 4  85561191439  2.19          6.66        4.65                True    False
#
#    units_per_case  cases_per_pallet  shelf_width  shelf_height  shelf_depth
# 0              30                14         16.9         12.60         7.40
# 1              18                 8         13.4          3.71        22.60
# 2              17                13         14.4         11.00         7.77
# 3              26                10         22.9         18.90         7.93
# 4               7                10         20.7         21.90        19.20

# %%
sales = sales.merge(products[['product_id', 'product_name']], 
                    on = ['product_id'], how = 'inner')

# %%
sales.head()
# Out:
#    product_id  store_id       date  sales         product_name_x  \
# 0           4         6 1997-01-01      4  Washington Cream Soda
# 1           4         7 1997-01-05      3  Washington Cream Soda
# 2           4         6 1997-01-06      2  Washington Cream Soda
# 3           4        17 1997-01-11      2  Washington Cream Soda
# 4           4        24 1997-01-11      2  Washington Cream Soda
#
#           product_name_y           product_name
# 0  Washington Cream Soda  Washington Cream Soda
# 1  Washington Cream Soda  Washington Cream Soda
# 2  Washington Cream Soda  Washington Cream Soda
# 3  Washington Cream Soda  Washington Cream Soda
# 4  Washington Cream Soda  Washington Cream Soda

# %% [markdown]
# ## Взаимное влияние продуктов друг на друга

# %%
sparse_sales = pd.pivot_table(sales, values='sales', index=['date', 'store_id'],
                     columns=['product_name'], fill_value = 0)

# %%
sparse_sales.head()
# Out:
# product_name         ADJ Rosy Sunglasses  Akron City Map  \
# date       store_id
# 1997-01-01 6                           0               0
#            14                          0               0
# 1997-01-02 11                          0               0
#            23                          0               0
# 1997-01-03 7                           0               0
#
# product_name         Akron Eyeglass Screwdriver  American Beef Bologna  \
# date       store_id
# 1997-01-01 6                                  0                      0
#            14                                 0                      0
# 1997-01-02 11                                 0                      0
#            23                                 0                      0
# 1997-01-03 7                                  0                      0
#
# product_name         American Chicken Hot Dogs  American Cole Slaw  \
# date       store_id
# 1997-01-01 6                                 0                   0
#            14                                0                   0
# 1997-01-02 11                                0                   0
#            23                                0                   0
# 1997-01-03 7                                 0                   0
#
# product_name         American Corned Beef  American Foot-Long Hot Dogs  \
# date       store_id
# 1997-01-01 6                            0                            0
#            14                           0                            0
# 1997-01-02 11                           0                            0
#            23                           0                            0
# 1997-01-03 7                            0                            0
#
# product_name         American Low Fat Bologna  American Low Fat Cole Slaw  \
# date       store_id
# 1997-01-01 6                                0                           0
#            14                               0                           0
# 1997-01-02 11                               0                           0
#            23                               0                           0
# 1997-01-03 7                                0                           0
#
# product_name                    ...               Washington Apple Juice  \
# date       store_id             ...
# 1997-01-01 6                    ...                                    0
#            14                   ...                                    0
# 1997-01-02 11                   ...                                    0
#            23                   ...                                    0
# 1997-01-03 7                    ...                                    0
#
# product_name         Washington Berry Juice  Washington Cola  \
# date       store_id
# 1997-01-01 6                              0                0
#            14                             0                0
# 1997-01-02 11                             0                0
#            23                             0                0
# 1997-01-03 7                              4                0
#
# product_name         Washington Cranberry Juice  Washington Cream Soda  \
# date       store_id
# 1997-01-01 6                                  0                      4
#            14                                 0                      0
# 1997-01-02 11                                 0                      0
#            23                                 0                      0
# 1997-01-03 7                                  0                      0
#
# product_name         Washington Diet Cola  Washington Diet Soda  \
# date       store_id
# 1997-01-01 6                            0                     0
#            14                           0                     0
# 1997-01-02 11                           0                     0
#            23                           0                     0
# 1997-01-03 7                            0                     0
#
# product_name         Washington Mango Drink  Washington Orange Juice  \
# date       store_id
# 1997-01-01 6                              0                        0
#            14                             0                        0
# 1997-01-02 11                             0                        0
#            23                             0                        0
# 1997-01-03 7                              0                        0
#
# product_name         Washington Strawberry Drink
# date       store_id
# 1997-01-01 6                                   0
#            14                                  0
# 1997-01-02 11                                  0
#            23                                  0
# 1997-01-03 7                                   0
#
# [5 rows x 1559 columns]

# %%
sales_correlation = sparse_sales.corr(method='spearman')

# %%
sales_correlation.head()
# Out:
# product_name                ADJ Rosy Sunglasses  Akron City Map  \
# product_name
# ADJ Rosy Sunglasses                    1.000000        0.097969
# Akron City Map                         0.097969        1.000000
# Akron Eyeglass Screwdriver             0.001993        0.022436
# American Beef Bologna                  0.041981        0.098703
# American Chicken Hot Dogs              0.050371        0.030165
#
# product_name                Akron Eyeglass Screwdriver  American Beef Bologna  \
# product_name
# ADJ Rosy Sunglasses                           0.001993               0.041981
# Akron City Map                                0.022436               0.098703
# Akron Eyeglass Screwdriver                    1.000000              -0.036888
# American Beef Bologna                        -0.036888               1.000000
# American Chicken Hot Dogs                     0.029858               0.027961
#
# product_name                American Chicken Hot Dogs  American Cole Slaw  \
# product_name
# ADJ Rosy Sunglasses                          0.050371           -0.033882
# Akron City Map                               0.030165            0.030935
# Akron Eyeglass Screwdriver                   0.029858            0.076507
# American Beef Bologna                        0.027961           -0.032650
# American Chicken Hot Dogs                    1.000000            0.014187
#
# product_name                American Corned Beef  American Foot-Long Hot Dogs  \
# product_name
# ADJ Rosy Sunglasses                    -0.007844                     0.077134
# Akron City Map                          0.031788                    -0.002137
# Akron Eyeglass Screwdriver             -0.005579                     0.123704
# American Beef Bologna                   0.027374                    -0.016565
# American Chicken Hot Dogs              -0.000718                     0.051069
#
# product_name                American Low Fat Bologna  \
# product_name
# ADJ Rosy Sunglasses                         0.019108
# Akron City Map                              0.047911
# Akron Eyeglass Screwdriver                  0.052521
# American Beef Bologna                      -0.041241
# American Chicken Hot Dogs                   0.048408
#
# product_name                American Low Fat Cole Slaw  \
# product_name
# ADJ Rosy Sunglasses                          -0.007614
# Akron City Map                                0.098667
# Akron Eyeglass Screwdriver                    0.088301
# American Beef Bologna                         0.070463
# American Chicken Hot Dogs                     0.058423
#
# product_name                           ...               \
# product_name                           ...
# ADJ Rosy Sunglasses                    ...
# Akron City Map                         ...
# Akron Eyeglass Screwdriver             ...
# American Beef Bologna                  ...
# American Chicken Hot Dogs              ...
#
# product_name                Washington Apple Juice  Washington Berry Juice  \
# product_name
# ADJ Rosy Sunglasses                       0.033237                0.112359
# Akron City Map                            0.005623                0.030795
# Akron Eyeglass Screwdriver               -0.006781                0.004975
# American Beef Bologna                     0.009394                0.063805
# American Chicken Hot Dogs                 0.082403               -0.019304
#
# product_name                Washington Cola  Washington Cranberry Juice  \
# product_name
# ADJ Rosy Sunglasses                0.076139                    0.018318
# Akron City Map                     0.039333                   -0.001983
# Akron Eyeglass Screwdriver         0.059180                    0.067207
# American Beef Bologna             -0.057211                   -0.022645
# American Chicken Hot Dogs          0.070678                    0.071697
#
# product_name                Washington Cream Soda  Washington Diet Cola  \
# product_name
# ADJ Rosy Sunglasses                      0.005265              0.018996
# Akron City Map                          -0.053719              0.013590
# Akron Eyeglass Screwdriver               0.046000             -0.016040
# American Beef Bologna                    0.005515              0.092713
# American Chicken Hot Dogs                0.036806              0.062295
#
# product_name                Washington Diet Soda  Washington Mango Drink  \
# product_name
# ADJ Rosy Sunglasses                     0.018471                0.099764
# Akron City Map                          0.040211                0.022333
# Akron Eyeglass Screwdriver             -0.003019                0.040994
# American Beef Bologna                  -0.007196                0.059298
# American Chicken Hot Dogs              -0.021510               -0.007004
#
# product_name                Washington Orange Juice  \
# product_name
# ADJ Rosy Sunglasses                        0.039577
# Akron City Map                             0.090423
# Akron Eyeglass Screwdriver                -0.001277
# American Beef Bologna                      0.059979
# American Chicken Hot Dogs                  0.105569
#
# product_name                Washington Strawberry Drink
# product_name
# ADJ Rosy Sunglasses                            0.018928
# Akron City Map                                 0.055622
# Akron Eyeglass Screwdriver                     0.108524
# American Beef Bologna                          0.040561
# American Chicken Hot Dogs                      0.000033
#
# [5 rows x 1559 columns]

# %%
product_name = 'American Chicken Hot Dogs'
sales_correlation[[product_name]].sort_values(product_name, ascending = True).head()
# Out:
# product_name                  American Chicken Hot Dogs
# product_name
# Lake Pimento Loaf                             -0.065509
# Fast Low Fat Chips                            -0.061037
# PigTail Frozen Sausage Pizza                  -0.058960
# Plato Decaf Coffee                            -0.058481
# Kiwi Lox                                      -0.057037

# %%
min_corr = pd.DataFrame(sales_correlation.min())
min_corr.columns = ['min']
min_corr.sort_values(by = 'min').head()
# Out:
#                                    min
# product_name
# Pearl Chardonnay Wine        -0.095018
# Carlson Whole Milk           -0.095018
# Gulf Coast Malted Milk Balls -0.092178
# Sunset Economy Toilet Brush  -0.092178
# Fast Fudge Brownies          -0.091463

# %%
max_corr = pd.DataFrame(sales_correlation.apply(lambda x : 
                                                np.max([*filter(lambda x : x != 1., x)]), 
                        axis = 1))
max_corr.columns = ['max']
max_corr.sort_values(by = 'max', ascending = False).head()
# Out:
#                                     max
# product_name
# Even Better Buttermilk         0.282014
# Sunset Toilet Paper            0.282014
# PigTail Frozen Chicken Breast  0.273921
# Club Mild Cheddar Cheese       0.273921
# Fast Strawberry Fruit Roll     0.273220

# %%
product_name = 'Plato French Roast Coffee'
sales_correlation[[product_name]].sort_values(product_name, ascending = False).head()
# Out:
# product_name                      Plato French Roast Coffee
# product_name
# Plato French Roast Coffee                          1.000000
# Just Right Vegetable Soup                          0.340598
# Hermanos Macintosh Apples                          0.289095
# Tell Tale Macintosh Apples                         0.273905
# Consolidated Whitening Toothpast                   0.247477
